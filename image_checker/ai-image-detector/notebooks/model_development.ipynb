# %% [markdown]
# # AI Image Detector
#
# This notebook is used for exploratory data analysis and model development for the AI-based image detection module that distinguishes between AI-generated and real images.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from src.detector import ImageDetector
from src.model import AIModel
from src.preprocessing import resize_image, normalize_image

# Load sample images
sample_images = []  # Add paths to sample images here

# Initialize the image detector
detector = ImageDetector()

# Example of loading and predicting an image
for img_path in sample_images:
    image = detector.load_image(img_path)
    prediction = detector.predict(image)
    print(f"Prediction for {img_path}: {prediction}")

# Visualize some sample images
def display_images(images):
    plt.figure(figsize=(15, 5))
    for i, img in enumerate(images):
        plt.subplot(1, len(images), i + 1)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
    plt.show()

# Call the display function
# display_images([detector.load_image(img) for img in sample_images])

# Further model training and evaluation can be added here.
